# %%
from pathlib import Path
import sys
nb_path = Path.cwd()
p = Path.cwd()
print(p)
for p in Path.cwd().parents:
    pa = p / "src"
    if pa.exists():
        print(pa)
        sys.path.insert(0,str(pa))
        break
print(pa)
#add
#sys.path.insert(0,str(pa))
import arenz_group_python
print(arenz_group_python.__path__)
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\set2
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']

# %%
import matplotlib.pyplot as plt
#from scipy.signal import 
from arenz_group_python import EC_Data, EC_Datas
from arenz_group_python import CV_Datas, CV_Data
from pathlib import Path
import sys

# %%
#Find CV files to plot
files = list(Path().glob('CV*.tdms'))

#Load all data files
datas = EC_Datas(files)

# %%
ecdatas = EC_Datas(files)

ecdatas.plot('E','i',y_smooth=20)
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src\arenz_group_python\data_treatment\ec_datas.py:59: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# <Axes: xlabel='x ( xunit)', ylabel='y (y_unit)'>

# %%
b = CV_Data(files[1])
b.plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 b = CV_Data(files[1])
#       2 b.plot()
#
# IndexError: list index out of range

# %%
b = EC_Data(files[0])
b.plot_rawdata()
print(b.name)
print(b.rate + b.rate + b.rate, b.setup["Pressure"])
print(float(b.rate))
# Out:
# CV_171019_ 3 : EC data sets:  7
# CV_171019_ 3
# 3.000e-02 V/s 291800 Pa
# 0.01

# %%
a = CV_Datas(files )
a.plot(title = "aaa")
# Out:
# neg first sweep
# neg first sweep
# <Axes: xlabel='E ( V)', ylabel='i (A)'>

# %%
qp,qn= a.integrate(-0.2,1.0,"all",True)
aa = a.weight
aa.value=10

print("Integration:",str(qp / a.area* a.area))
a.norm("area")
print("Integration_",a.integrate(-0.2,0.0,"all",True))
print(files[1])
a.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 qp,qn= a.integrate(-0.2,1.0,"all",True)
#       2 aa = a.weight
#       3 aa.value=10
#
# AttributeError: 'CV_Datas' object has no attribute 'integrate'

# %%
cv = CV_Datas(files[11:13])
cv.plot()
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src\arenz_group_python\data_treatment\cv_datas.py:182: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   CV_plot.legend()
# <Axes: xlabel='x ( xunit)', ylabel='y (y_unit)'>
