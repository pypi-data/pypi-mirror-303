# %%
import era5tools

# %%
era5 = era5tools.ERA5(cdsapi_key='64f07ded-6284-44c1-be30-a9db39516a84')

# %%
era5.download('sst','.', year_range=(2024,2024), months=[6], overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/.venv/ipyleaflet/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/.venv/ipyleaflet/lib/python3.11/site-packages/urllib3/connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#
# File ~/.venv/ipyleaflet/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
# ...

# %%
ds = era5.proc('.', 'sst', (2024,2024))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/.venv/ipyleaflet/lib/python3.11/site-packages/xarray/core/concat.py:230, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     229 try:
# --> 230     first_obj, objs = utils.peek_at(objs)
#     231 except StopIteration:
#
# File ~/.venv/ipyleaflet/lib/python3.11/site-packages/xarray/core/utils.py:188, in peek_at(iterable)
#     187 gen = iter(iterable)
# --> 188 peek = next(gen)
#     189 return peek, itertools.chain([peek], gen)
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ds = era5.proc('.', 'sst', (2024,2024))
#
# ...

# %%
ds.sel(time='2024-09-01', number=1)['mean'].plot();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds.sel(time='2024-09-01', number=1)['mean'].plot();
#
# NameError: name 'ds' is not defined
